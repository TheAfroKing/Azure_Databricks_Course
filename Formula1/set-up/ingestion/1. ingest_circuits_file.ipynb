# %% [markdown]
# Ingest Circuits.csv file

# %% [markdown]
# Read the csv file using the spark dataframe readaer

# %%
# %run "../includes/common_functions"

# %%
# %run "../includes/configuration"

# %%
#dbutils.ls('abfss://raw@f1datalakefp.dfs.core.windows.net/circuits.csv')

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("p_date_source","")
#dbutils.widgets.dropdown("p_date_source","Testing",["Testing","Production"])
v_data_source=dbutils.widgets.get("p_date_source")

# %%
#circuits_df = spark.read.csv("abfs://demo@f1datalakefp.dfs.core.windows.net/circuits.csv",header=True,inferSchema=True)

# %% [markdown]
# ## Select stament

# %%
#circuit_selected_df = circuits_df.select("circuitId","circuitRef","name","location","country",circuits_df.lat.alias("latitude"),circuits_df.lng.alias("longitude"),circuits_df.alt.alias("altitude"))

# %%
#circuit_selected_df = circuits_df.select(circuits_df.circuitId,circuits_df.circuitRef,circuits_df.name,circuits_df.location,circuits_df.country,circuits_df.lat.alias("latitude"),circuits_df.lng.alias("longitude"),circuits_df.alt.alias("altitude"))

# %%
#circuit_selected_df = circuits_df.select(circuits_df["circuitId"],circuits_df["circuitRef"],circuits_df["name"],circuits_df["location"],circuits_df["country"],circuits_df["lat"].alias("latitude"),circuits_df["lng"].alias("longitude"),circuits_df["alt"].alias("altitude"))

# %%
#from pyspark.sql.functions import col

# %%
#circuit_selected_df = circuits_df.select(col("circuitId"),col("circuitRef"),col("name"),col("location"),col("country"),col("lat").alias("latitude"),col("lng").alias("longitude"),col("alt").alias("altitude"))

# %% [markdown]
# ## Rename the Column Names

# %%
#circuits_renamed_df = circuits_df.withColumnRenamed("lat", "latitude").withColumnRenamed("lng", "longitude").withColumnRenamed("alt", "altitude")
#display(circuits_renamed_df)

# %% [markdown]
# ## Create dataframe ussing schema

# %%
#circuits_df = spark.read.schema("circuitId INT, circuitRef STRING, name STRING, location STRING, country STRING, latitude DOUBLE, longitude DOUBLE, altitude INT").csv("abfs://demo@f1datalakefp.dfs.core.windows.net/circuits.csv",header=True)

# %%
#display(circuits_df)

# %%
#circuits_df.printSchema()

# %%
#circuits_df.describe().show()

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType
from pyspark.sql.functions import current_timestamp,to_date,current_date,lit

# %%
circuits_schema = StructType(fields=[StructField("circuit_id", IntegerType(), False),
                                     StructField("circuit_ref", StringType(), True),
                                     StructField("name", StringType(), True),
                                     StructField("location", StringType(), True),
                                     StructField("country", StringType(), True,),
                                     StructField("latitude", DoubleType(), True),
                                     StructField("longitude", DoubleType(), True),
                                     StructField("altitude", IntegerType(), True)
                                    ])
circuits_df = spark.read.schema(circuits_schema).csv(f"{raw_folder_path}/circuits.csv",header=True)

# %% [markdown]
# ## Add a column
# - withColumn function add a column
# - current_timeStampt return the current timestamp as a column
# - current_date return the current date as a column
# - lit converts a literal value to a column

# %%
circuits_df = add_ingestion_timestamp(circuits_df)
circuits_df = add_data_source(circuits_df,v_data_source)

# %%
display(circuits_df)

# %% [markdown]
# ## Write DF into parquet file

# %%
circuits_df.write.mode("overwrite").parquet(f"{processed_folder_path}/circuits")

# %%
#display(dbutils.fs.ls("abfs://processed@f1datalakefp.dfs.core.windows.net/circuits"))

# %%
#df = spark.read.parquet("abfs://processed@f1datalakefp.dfs.core.windows.net/circuits")

# %%
#display(df)

# %%
dbutils.notebook.exit("Success")
