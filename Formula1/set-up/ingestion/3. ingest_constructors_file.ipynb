# %% [markdown]
# # Ingest Constructors.json file Assignment

# %% [markdown]
# ## Assignment
# - create a DF loading the constructors.json file in the raw container
# - rename columns to (constructor_id,constructor_ref)
# - add a new columns ingestion_timestampt
# - save the file in parquet file in the processed container.
# - verify the schema of the partquet file

# %%
# %run "../includes/common_functions"

# %%
# %run "../includes/configuration"

# %%
dbutils.widgets.text("p_date_source","")
#dbutils.widgets.dropdown("p_date_source","Testing",["Testing","Production"])
v_data_source=dbutils.widgets.get("p_date_source")

# %%
from pyspark.sql.functions import current_timestamp,col

# %%
constructors_schema="constructorId INT,constructorRef STRING,name STRING,nationality STRING"

# %%
constructors_df = spark.read.schema(constructors_schema).json(f"{raw_folder_path}/constructors.json")

# %%
constructors_df = constructors_df.select(col('constructorId').alias('constructor_id'),col('constructorRef').alias('constructor_ref'),col('name'),col('nationality'))

# %%
constructors_df = add_ingestion_timestamp(constructors_df)
constructors_df = add_data_source(constructors_df,v_data_source)

# %%
#display(constructors_df)

# %% [markdown]
# ## Write DF into parquet file

# %%
#constructors_df.write.mode("overwrite").parquet(f"{processed_folder_path}/constructors")

# %%
constructors_df.write.mode("overwrite").format("parquet").saveAsTable("f1_processed_db.constructors")

# %%
#df=spark.read.parquet(f"{processed_folder_path}/constructors")
#df.printSchema()

# %%
dbutils.notebook.exit("Success")
