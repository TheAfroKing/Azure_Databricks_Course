# %%
 # %run "../includes/configuration"

# %%
df= spark.read.parquet(f"{processed_folder_path}/races")

# %%
#df_filtered = df.filter("race_year= 2019 and round<=5")
#df_filtered = df.where("race_year= 2019 and round<=5")
#df_filtered = df.where((df.race_year == 2019) & (df.round <= 5))
df_filtered = df.filter((df.race_year == 2019) & (df.round <= 5))

# %%
display(df_filtered)
