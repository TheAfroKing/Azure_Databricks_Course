# %%
raw_folder_path='abfss://raw@f1datalakefp.dfs.core.windows.net'
processed_folder_path='abfss://processed@f1datalakefp.dfs.core.windows.net'
presentation_folder_path='abfss://presentation@f1datalakefp.dfs.core.windows.net'
