# %% [markdown]
# # Access Azure Data Lake using access keys
# 1. Set the spark config fs azure account key
# 2. List Files From demo container
# 3. Read data frin circuits.csv file

# %%
spark.conf.set("fs.azure.account.key.f1datalakefp.dfs.core.windows.net","access_key")

# %%
dbutils.fs.ls("abfs://demo@f1datalakefp.dfs.core.windows.net/circuits.csv")

# %%
display(spark.read.csv("abfs://demo@f1datalakefp.dfs.core.windows.net/circuits.csv"))
